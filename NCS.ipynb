# %%
import requests
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup

# %%
url='https://www.ncs.gov.in/Pages/Search.aspx?lm=cUdiqrBi2j8aparMq6PhBK3hHroMgUqJlhvOWErxqp4%3D&OT=fheFJjl41aGWG85YSvGqng%3D%3D&Source=https://www.ncs.gov.in/&V=6gqhwycyVHE%3D'

# %%
user_agent='Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
headers={'User-Agent':user_agent}

# %%
request=urllib.request.Request(url,None,headers)

# %%
response=urllib.request.urlopen(request)

# %%
data=response.read()

# %%
soup=BeautifulSoup(data,"html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html >
#
# <html dir="ltr" lang="en-us">
# ...

# %%
cards=soup.find_all('div',attrs={'class':'col-md-12 paddingTop5'})

# %%
onclick=[]
i=0
for card in cards:
    links=card.find_all('a')
    i=i+1
    #print(i)
    print('Job Title:{}'.format(links[0].text))
    company=card.find_all('span',attrs={'class':"text-info"})
    #print(company[0].text)
    Company_name=card.find_all('a',attrs={'class':'CheckBtn'})
    print('Company Name: ',Company_name[0].text)
    location=card.find_all('span',attrs={'class':'text-success'})
    print('Job location:',location[0].text)
    print('Salary: ',location[1].text)
    print('Skills Required: ',location[2].text)
    JD=card.find_all('span',attrs={'ms-displayBlock wordBreak'})
    print('Job Desc: ',JD[0].text)
    
    print('--'*40)
    #print(company)
# Out:
# Job Title:
# Teacher
#
#
#
# Company Name:  Cassius Technologies Private Limited
# Job location:
# Raichur; Karnataka
# Salary:
# 240000 - 600000 (per annum)
# Skills Required:
# NA
# Job Desc:
#                                             Vacancies available in raichur and hassan  with good remuneration and free accommodation
# --------------------------------------------------------------------------------
# Job Title:
# MBA Marketing Interns
#
#
#
# Company Name:  Cassius Technologies Private Limited
# Job location:
# Bangalore; Karnataka
# Salary:
# 24000 - 60000 (per annum)
# Skills Required:
# NA
# Job Desc:
#                                             Summer Internships for marketing (Work from Home: due to Covid 19)Looking for great communication and marketing enthusiast interns to lean and get exposure to help us market our services across India. Immediate need for MBA Marketing Interns
#
#                                                 Read more...
#
# ...
